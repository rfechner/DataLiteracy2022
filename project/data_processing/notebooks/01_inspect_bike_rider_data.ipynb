# %% [markdown]
# # Inspect the bike rider count data

# %% [markdown]
# For the raw bike rider counts data, a detailed description of the dataset is missing. Therefore, we investigate what the rows and columns represent.
#
# The results of this inspection are summarized at the end of this notebook.

# %% [markdown]
# ## Data Import
#
# Import the raw bike rider counts data.

# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
import datetime
from datetime import datetime
from datetime import timedelta, date

# %%
# paths to data (one file per month)
dat_paths = ['./../../data/raw/eco_counter_fahrradzaehler_20210' + str(i) + '.csv' for i in range(1,10)]
dat_paths = dat_paths + ['./../../data/raw/eco_counter_fahrradzaehler_2021' + str(i) + '.csv' for i in range(10,13)]
dat_paths = dat_paths + ['./../../data/raw/eco_counter_fahrradzaehler_20220' + str(i) + '.csv' for i in range(1,10)]

# read in the data
dats = [pd.read_csv(path) for path in dat_paths]

# concatenate monthly data to get data of whole year in one dataframe
dat = pd.concat(dats)

# %%
# check whether import of data worked
dat.head()
# Out:
#                   timestamp             iso_timestamp  zählstand  stand  \
# 0  2021-01-01T01:00:00+0000  2021-01-01T01:00:00+0100          2      0
# 1  2021-01-01T02:00:00+0000  2021-01-01T02:00:00+0100          0      0
# 2  2021-01-01T03:00:00+0000  2021-01-01T03:00:00+0100          1      0
# 3  2021-01-01T04:00:00+0000  2021-01-01T04:00:00+0100          1      0
# 4  2021-01-01T05:00:00+0000  2021-01-01T05:00:00+0100          2      0
#
#            standort             channel_name  channel_id counter_site  \
# 0  Stadt Heidelberg  Channel 1 Richtung West   101012161        Plöck
# 1  Stadt Heidelberg  Channel 1 Richtung West   101012161        Plöck
# 2  Stadt Heidelberg  Channel 1 Richtung West   101012161        Plöck
# 3  Stadt Heidelberg  Channel 1 Richtung West   101012161        Plöck
# 4  Stadt Heidelberg  Channel 1 Richtung West   101012161        Plöck
#
#    counter_site_id                                        domain_name  \
# 0        100012161  NVBW - Nahverkehrsgesellschaft Baden- Württemberg
# 1        100012161  NVBW - Nahverkehrsgesellschaft Baden- Württemberg
# 2        100012161  NVBW - Nahverkehrsgesellschaft Baden- Württemberg
# 3        100012161  NVBW - Nahverkehrsgesellschaft Baden- Württemberg
# 4        100012161  NVBW - Nahverkehrsgesellschaft Baden- Württemberg
#
#    domain_id  longitude  latitude                       timezone  interval  \
# 0       6598   8.698543  49.40913  (UTC+01:00) Europe/Berlin;DST        15
# 1       6598   8.698543  49.40913  (UTC+01:00) Europe/Berlin;DST        15
# 2       6598   8.698543  49.40913  (UTC+01:00) Europe/Berlin;DST        15
# 3       6598   8.698543  49.40913  (UTC+01:00) Europe/Berlin;DST        15
# 4       6598   8.698543  49.40913  (UTC+01:00) Europe/Berlin;DST        15
#
#   counter_serial
# 0    Y2H22032496
# 1    Y2H22032496
# 2    Y2H22032496
# 3    Y2H22032496
# 4    Y2H22032496

# %% [markdown]
# ## Data Inspection

# %% [markdown]
# One row in the raw data represents one hourly bike rider count measurement.
# Each column represents an attribute of a measurement. Find out what these attributes are and what values they take:

# %%
# initialize dataframe that yields an overview of the data contained in 'dat'
overview_df = pd.DataFrame(columns=['colname', 'number_of_unique_values_in_column', 'example_values'])

# For each column in the dataframe 'dat', determine the number of unique values
# that the column contains, and draw (maximum) 4 example values from each column
# to illustrate which values occur in the column.
for colname in dat.columns:

    # unique values in column
    unique_values = list(set(dat[colname]))

    # pick maximum 4 values from unique-values-set (as examples)
    example_values = random.sample(unique_values, k=min(4, len(unique_values)))

    # add information about the currently considered column to the overview dataframe
    new_row = pd.DataFrame.from_dict(
        {'colname' : colname,
        'number_of_unique_values_in_column' : len(unique_values),
        'example_values' : example_values
        }, orient='index').T
    overview_df = pd.concat([overview_df, new_row], ignore_index = True)

with pd.option_context('max_colwidth', 800):
    display(overview_df)
# Out:
#             colname number_of_unique_values_in_column  \
# 0         timestamp                             15291
# 1     iso_timestamp                             15291
# 2         zählstand                               740
# 3             stand                                 2
# 4          standort                                 6
# 5      channel_name                                77
# 6        channel_id                               109
# 7      counter_site                                25
# 8   counter_site_id                                25
# 9       domain_name                                 1
# 10        domain_id                                 1
# 11        longitude                                25
# 12         latitude                                25
# 13         timezone                                 2
# 14         interval                                 1
# 15   counter_serial                                25
#
#                                                                                                                   example_values
# 0                       [2021-04-16T11:00:00+0000, 2021-02-20T16:00:00+0000, 2022-04-30T12:00:00+0000, 2021-06-09T23:00:00+0000]
# 1                       [2021-08-15T06:00:00+0200, 2021-08-06T13:00:00+0200, 2022-07-10T09:00:00+0200, 2022-04-06T11:00:00+0200]
# 2                                                                                                           [665, 301, 293, 142]
# 3                                                                                                                         [4, 0]
# 4                                                           [Stadt Konstanz, Stadt Heidelberg, Stadt Freiburg, Stadt Ludwisburg]
# 5   [S-Bahn Haltestelle Fürstenberg Cyclist OUT, Zugwiesen Stadtauswärts, Bismarckstraße Stadteinwärts, Channel 3 Richtung West]
# 6                                                                                   [102057246, 101049883, 103049883, 353255196]
# 7                                                 [Hardtstraße, Bismarckstraße, Gaisbergstraße, FR2 Güterbahn / Ferd.-Weiß-Str.]
# 8                                                                                   [100057246, 100013034, 300015452, 300020056]
# 9                                                                            [NVBW - Nahverkehrsgesellschaft Baden- Württemberg]
# 10                                                                                                                        [6598]
# 11                                                                               [9.17190492153168, 7.8623013, 7.83717, 9.17467]
# 12                                                                 [48.90932869563591, 48.883562725714086, 49.406723, 47.673801]
# 13                                                                 [(UTC+01:00) Europe/Paris;DST, (UTC+01:00) Europe/Berlin;DST]
# 14                                                                                                                          [15]
# 15                                                                          [COM21020460, Y2H20083632, Y2H18106689, Y2H18106691]

# %% [markdown]
# Quick observations from this overview and dat.head() above:
#
# - Data was collected hourly: 'zählstand' represents the bike riders passing a counting station within 1 hour.
# - Data was collected in 6 cities (see: the number of unique values in column 'standort' is 6), at 25 counter sites (see: the number of unique values in column 'counter_site' is 25) in total.
# - 'channel_name' probably specifies different channels (count series) at one counting station, e.g., by naming the direction of travel.

# %% [markdown]
# ### Inspect timestamp of measurements

# %%
# make 'timestamp' date
dat['timestamp'] = pd.to_datetime(dat['timestamp'])

# %%
# check whether there are measurements taken at midnight
example_midnight_dates = [pd.Timestamp('2021-03-0' + str(i)+ 'T00', tz='UTC') for i in np.arange(1,10)]
if(len(dat[dat['timestamp'].isin(example_midnight_dates)]) > 0):
    print('There are measurements taken at midnight.')
# Out:
# There are measurements taken at midnight.

# %% [markdown]
# Some measurements are collected at midnight. We have to correct the date for those measurements because they reflect bikers that passed the counting station in the hour before midnight, i.e., on the "day before".

# %%
# For each measurement (row), we want to know on which day the data was 
# collected. In order to adjust for counts collected at midnight, we shift the 
# daytime by 1 second before converting it to date.
# (Thereby, we can simply compute daily sums in the cell below;
#  adding "midnight counts" to the day before by shifting the daytime by 1 sec.)
dat['date'] = (dat['timestamp'] - pd.Timedelta(1, 'sec')).dt.date

# %% [markdown]
# ### Inspect nesting of location information
#
# 'standort' --> 'counter_site'/'counter_site_id'/'counter_serial'/'latitude'+'longitude' --> 'channel_name'/'channel_id'

# %% [markdown]
# In the following, we check whether the location data is really nested as the quick observations above suggest, namely:
# There are different 'standort' (cities).
# Within each of 'standort' (city), there are different 'counter_site' (e.g., different streets).
# And at each 'counter_site', different count series (so-called "channels") are measured in parallel, e.g., in different directions of travel. 'channel_name' / 'channel_id' discriminates between these different channels.
# NOTE: As we will see below, 'channel_name' provides a distinction between channels that is more coarse than the distinction made by 'channel_id'; i.e., 'channel_id' is nested within 'channel_name'.

# %% [markdown]
# #### 'standort'

# %%
cities = list(set(dat['standort']))
print('The dataset contains bike rider counts for the following cities:', cities)
# Out:
# The dataset contains bike rider counts for the following cities: ['Stadt Heidelberg', 'Stadt Freiburg', 'Stadt Offenburg', 'Stadt Konstanz', 'Stadt Ludwisburg', 'Stadt Ulm']

# %% [markdown]
# #### 'counter_site'/'counter_site_id'/'counter_serial'/'latitude'+'longitude'

# %%
# overview over counter sites
dat.groupby(['standort', 'counter_site'], as_index=False).size()
# size reflects the number of datapoints collected at the counter site
# Out:
#             standort                         counter_site   size
# 0     Stadt Freiburg         FR1 Dreisam / Otto-Wels-Str.  30582
# 1     Stadt Freiburg      FR2 Güterbahn / Ferd.-Weiß-Str.  15291
# 2     Stadt Freiburg          FR3 Eschholzstr. / Egonstr.  30582
# 3   Stadt Heidelberg                   Bahnstadtpromenade  88302
# 4   Stadt Heidelberg                       Gaisbergstraße  91746
# 5   Stadt Heidelberg                          Hardtstraße  61164
# 6   Stadt Heidelberg                    Mannheimer Straße  76455
# 7   Stadt Heidelberg                                Plöck  91746
# 8   Stadt Heidelberg             Schlierbacher Landstraße  52328
# 9   Stadt Heidelberg              Ziegelhäuser Landstraße  53224
# 10    Stadt Konstanz                       Fahrradbruecke  61164
# 11    Stadt Konstanz       S-Bahn Haltestelle Fürstenberg  27287
# 12    Stadt Konstanz  S-Bahn-Haltestelle Petershausen-Süd  27287
# 13  Stadt Ludwisburg                         Alleenstraße  91746
# 14  Stadt Ludwisburg                       Bismarckstraße  86076
# 15  Stadt Ludwisburg               Friedrich-Ebert-Straße  58100
# 16  Stadt Ludwisburg                             Fuchshof  61164
# 17  Stadt Ludwisburg     Kesseläcker (Verl. Nussackerweg)  59764
# 18  Stadt Ludwisburg                     Schlieffenstraße  60124
# 19  Stadt Ludwisburg                        Schlossstraße  87630
# 20  Stadt Ludwisburg                            Seestraße  61164
# 21  Stadt Ludwisburg                        Solitudeallee  29938
# 22  Stadt Ludwisburg                            Zugwiesen  87630
# 23   Stadt Offenburg                      Hauptstraße neu  13365
# 24         Stadt Ulm                 Blautal Lupferbrücke  11504

# %%
# overview over counter sites, adding 'counter_site_id', 'counter_serial', 'latitude'+'longitude' information
dat.groupby(['standort', 'counter_site', 'counter_site_id', 'counter_serial', 'latitude', 'longitude'], as_index=False).size()
# Out:
#             standort                         counter_site  counter_site_id  \
# 0     Stadt Freiburg         FR1 Dreisam / Otto-Wels-Str.        100014585
# 1     Stadt Freiburg      FR2 Güterbahn / Ferd.-Weiß-Str.        100014511
# 2     Stadt Freiburg          FR3 Eschholzstr. / Egonstr.        100017109
# 3   Stadt Heidelberg                   Bahnstadtpromenade        100056770
# 4   Stadt Heidelberg                       Gaisbergstraße        100012608
# 5   Stadt Heidelberg                          Hardtstraße        100056769
# 6   Stadt Heidelberg                    Mannheimer Straße        100013034
# 7   Stadt Heidelberg                                Plöck        100012161
# 8   Stadt Heidelberg             Schlierbacher Landstraße        100049883
# 9   Stadt Heidelberg              Ziegelhäuser Landstraße        100049901
# 10    Stadt Konstanz                       Fahrradbruecke        100046462
# 11    Stadt Konstanz       S-Bahn Haltestelle Fürstenberg        300016792
# 12    Stadt Konstanz  S-Bahn-Haltestelle Petershausen-Süd        300016793
# 13  Stadt Ludwisburg                         Alleenstraße        100041999
# 14  Stadt Ludwisburg                       Bismarckstraße        300015617
# 15  Stadt Ludwisburg               Friedrich-Ebert-Straße        300020056
# 16  Stadt Ludwisburg                             Fuchshof        300014706
# 17  Stadt Ludwisburg     Kesseläcker (Verl. Nussackerweg)        300015457
# 18  Stadt Ludwisburg                     Schlieffenstraße        300014392
# 19  Stadt Ludwisburg                        Schlossstraße        300015452
# 20  Stadt Ludwisburg                            Seestraße        300014866
# 21  Stadt Ludwisburg                        Solitudeallee        300015618
# 22  Stadt Ludwisburg                            Zugwiesen        300015458
# 23   Stadt Offenburg                      Hauptstraße neu        100036542
# 24         Stadt Ulm                 Blautal Lupferbrücke        100057246
#
#    counter_serial   latitude  longitude   size
# 0     Y2H18076077  47.990540   7.862301  30582
# 1     Y2H21070299  47.998592   7.822082  15291
# 2     Y2H22012076  47.999840   7.837170  30582
# 3     Y2H19111385  49.397709   8.672679  88302
# 4     YTH15078127  49.406723   8.694240  91746
# 5     Y2H19111384  49.388638   8.676693  61164
# 6     Y2G14014962  49.411800   8.659140  76455
# 7     Y2H22032496  49.409130   8.698543  91746
# 8     Y2H18106691  49.414705   8.718396  52328
# 9     Y2H18106689  49.419259   8.725964  53224
# 10    YTH18075911  47.669360   9.174670  61164
# 11    COM21020459  47.677375   9.162819  27287
# 12    COM21020460  47.673801   9.173952  27287
# 13    YTH17113795  48.893189   9.192943  91746
# 14    Y2H20083638  48.899039   9.181309  86076
# 15    Y2H21090554  48.893033   9.206430  58100
# 16    Y2H20083632  48.890275   9.219911  61164
# 17    Y2H20083636  48.901772   9.171905  59764
# 18    Y2H20083634  48.893767   9.164309  60124
# 19    Y2H20083637  48.900224   9.194173  87630
# 20    Y2H20093657  48.889513   9.190568  61164
# 21    Y2H20083643  48.883563   9.182725  29938
# 22    Y2H20083640  48.909329   9.240983  87630
# 23    Y2H17021563  48.467990   7.942310  13365
# 24    Y2H19121610  48.400800   9.957680  11504

# %% [markdown]
# --> 'counter_site', 'counter_site_id', 'counter_serial', 'latitude' together with 'longitude' provide the same information. They tell us where in the city the counting station is located.
#
# (Since we do not have mappings of 'counter_site_id' or 'counter_serial' to actual locations, we will use the information provided by 'latitude'+'longitude'.)

# %% [markdown]
# #### 'channel_name'/'channel_id'

# %%
# overview over number of datapoints collected at the channels with given channel names
dat.groupby(['standort', 'counter_site', 'channel_name'], as_index=False).size()
# Out:
#             standort                     counter_site  \
# 0     Stadt Freiburg     FR1 Dreisam / Otto-Wels-Str.
# 1     Stadt Freiburg     FR1 Dreisam / Otto-Wels-Str.
# 2     Stadt Freiburg  FR2 Güterbahn / Ferd.-Weiß-Str.
# 3     Stadt Freiburg      FR3 Eschholzstr. / Egonstr.
# 4     Stadt Freiburg      FR3 Eschholzstr. / Egonstr.
# ..               ...                              ...
# 84  Stadt Ludwisburg                        Zugwiesen
# 85  Stadt Ludwisburg                        Zugwiesen
# 86   Stadt Offenburg                  Hauptstraße neu
# 87         Stadt Ulm             Blautal Lupferbrücke
# 88         Stadt Ulm             Blautal Lupferbrücke
#
#                            channel_name   size
# 0          FR1 Dreisam / Hindenburgstr.  15291
# 1   FR1 Dreisam / Hindenburgstr. [Bike]  15291
# 2       FR2 Güterbahn / Ferd.-Weiß-Str.  15291
# 3         Richtung Norden (Zelt 01_OUT)  15291
# 4           Richtung Süden (Zelt 01_IN)  15291
# ..                                  ...    ...
# 84              Zugwiesen Stadtauswärts  43815
# 85              Zugwiesen Stadteinwärts  43815
# 86                      Hauptstraße neu  13365
# 87       Blautal Lupferbrücke Ri. Stadt   5752
# 88       Blautal Lupferbrücke Ri. Süden   5752
#
# [89 rows x 4 columns]

# %%
# overview over number of datapoints collected at the channels with given channel ID
dat.groupby(['standort', 'counter_site', 'channel_id'], as_index=False).size()
# Out:
#             standort                     counter_site  channel_id   size
# 0     Stadt Freiburg     FR1 Dreisam / Otto-Wels-Str.   101014585  15291
# 1     Stadt Freiburg     FR1 Dreisam / Otto-Wels-Str.   353234627  15291
# 2     Stadt Freiburg  FR2 Güterbahn / Ferd.-Weiß-Str.   101014511  15291
# 3     Stadt Freiburg      FR3 Eschholzstr. / Egonstr.   101017109  15291
# 4     Stadt Freiburg      FR3 Eschholzstr. / Egonstr.   102017109  15291
# ..               ...                              ...         ...    ...
# 104  Stadt Offenburg                  Hauptstraße neu   101036542  13365
# 105        Stadt Ulm             Blautal Lupferbrücke   101057246   2876
# 106        Stadt Ulm             Blautal Lupferbrücke   102057246   2876
# 107        Stadt Ulm             Blautal Lupferbrücke   103057246   2876
# 108        Stadt Ulm             Blautal Lupferbrücke   104057246   2876
#
# [109 rows x 4 columns]

# %%
print('number of unique channel names:', len(list(set(dat['channel_name']))))
print('number of unique channel IDs:', len(list(set(dat['channel_id']))))
# Out:
# number of unique channel names: 77
# number of unique channel IDs: 109

# %% [markdown]
# --> Since the numbers of unique channel names and unique channel IDs differ, there cannot be a 1-to-1-mapping between 'channel_name' and 'channel_id'. The two columns provide different information.
# Since there are more channel IDs than channel names, we assume that channel IDs are nested within channel names. In other words, we assume that at one channel site identified by the channel's name, mutliple count series (channels) are collected (identified by the channel's ID).
# Check this assumption:

# %%
# If channel ID is nested within channel name, we should find a unique channel name for each channel ID.
# Check this.

# get all channel IDs
channel_ids = list(set(dat['channel_id']))

# Initialize a list in which we store for each channel ID with how many different
# channel names it occurs together.
list_of_num_channel_names_for_id = []

# For each channel ID, check with how many different channel names it occurs 
# together.
for id in channel_ids:

    # extract data for channel id
    dat_id = dat[dat['channel_id'] == id]

    # check number of channel names for each id,
    # should be 1 if mapping from id to channel_name was unique
    num_channel_names_for_id = len(set(dat_id['channel_name']))

    list_of_num_channel_names_for_id.append(num_channel_names_for_id)

print('A single channel ID occurs with up to', max(np.unique(list_of_num_channel_names_for_id)), 'channel names together.')
# Out:
# A single channel ID occurs with up to 2 channel names together.

# %% [markdown]
# --> There are channel IDs that occur together with two distinct channel names.

# %%
# find channel IDs which occur together with two distinct channel names

# indices of channel IDs that occur with 2 channel names
cID_indices = [i for i, e in enumerate(list_of_num_channel_names_for_id) if e == 2]
print('Number of channel IDs that occur together with two channel names:', len(cID_indices))

channel_ids_with_two_channel_names = [channel_ids[e] for i, e in enumerate(cID_indices)]
print('Channel IDs that occur together with two channel names:', channel_ids_with_two_channel_names)
# Out:
# Number of channel IDs that occur together with two channel names: 4
# Channel IDs that occur together with two channel names: [353239372, 353239373, 353239374, 353239375]

# %%
# sum counts of one day at one counting station
counters_by_daytype_daily = dat.groupby(by=['standort', 'counter_site', 'channel_name', 'channel_id', 'longitude', 'latitude', 'date'], as_index=False)['zählstand'].sum()

# for each channel ID that occurs together with two distinct channel names
for id in channel_ids_with_two_channel_names:

    # channel names with which the given channel ID occurs together
    channel_names_for_id = list(set(dat[dat['channel_id'] == id]['channel_name']))
    counter_sites_for_id = list(set(dat[dat['channel_id'] == id]['counter_site']))
    standorts_for_id = list(set(dat[dat['channel_id'] == id]['standort']))

    # extract data of this channel
    dat_for_id = counters_by_daytype_daily[counters_by_daytype_daily['channel_id'] == id]
    
    # plot daily bike rider counts collected by channel with given ID,
    # seperate between different 'channel_name'-values

    # initialize figure
    plt.figure()
    
    # for each value of 'channel_name', plot daily number of bike rider counts
    for channel_name_for_id in channel_names_for_id:
        plt.plot(
            dat_for_id[dat_for_id['channel_name'] == channel_name_for_id]['date'],
            dat_for_id[dat_for_id['channel_name'] == channel_name_for_id]['zählstand'],
            label='channel name: ' + channel_name_for_id)
    
    # add title and legend
    plt.title('channel ID: ' + str(id) + '\nstandort: ' + str(set(dat_for_id['standort'])) + '\ncounter sites: ' + str(set(dat_for_id['counter_site'])))
    plt.legend()

# %% [markdown]
# Apparently, the channels ('Schlieffenstraße Stadteinwärts', 'Schlieffenstraße Stadtauswärts') were renamed at the beginning of May in 2021 (whereas their ID was not changed).

# %%
# find date at which renaming happened

# for each channel ID that occurs together with two distinct channel names,
# print the channel ID and channel name together and check when data was collected
for id in channel_ids_with_two_channel_names:

    channel_names_for_id = list(set(dat[dat['channel_id'] == id]['channel_name']))
    counter_sites_for_id = list(set(dat[dat['channel_id'] == id]['counter_site']))
    standorts_for_id = list(set(dat[dat['channel_id'] == id]['standort']))

    # print
    print('channel ID:', id, '| standort:', standorts_for_id, '| counter_sites:', counter_sites_for_id, '| channel names:', channel_names_for_id)
    
    # check length and dates for data of channel with given channel_id and channel_name
    for channel_name_for_id in channel_names_for_id:
        dat_id_channelname = dat[(dat.standort == standorts_for_id[0]) & (dat.counter_site == counter_sites_for_id[0]) & (dat.channel_id == id) & (dat.channel_name == channel_name_for_id)]
        print('\tdataset for channel_name', channel_name_for_id, '\t: length of dataset: \t', len(dat_id_channelname), '\t min date:', min(dat_id_channelname['timestamp']), '\t max date:', max(dat_id_channelname['timestamp']))
# Out:
# channel ID: 353239372 | standort: ['Stadt Ludwisburg'] | counter_sites: ['Schlieffenstraße'] | channel names: ['Schlieffenstraße Stadteinwärts A', 'Schlieffenstraße Stadteinwärts']
# 	dataset for channel_name Schlieffenstraße Stadteinwärts A 	: length of dataset: 	 2876 	 min date: 2021-01-01 01:00:00+00:00 	 max date: 2021-04-30 23:00:00+00:00
# 	dataset for channel_name Schlieffenstraße Stadteinwärts 	: length of dataset: 	 12155 	 min date: 2021-05-01 01:00:00+00:00 	 max date: 2022-09-20 03:00:00+00:00
# channel ID: 353239373 | standort: ['Stadt Ludwisburg'] | counter_sites: ['Schlieffenstraße'] | channel names: ['Schlieffenstraße Stadtauswärts A', 'Schlieffenstraße Stadtauswärts']
# 	dataset for channel_name Schlieffenstraße Stadtauswärts A 	: length of dataset: 	 2876 	 min date: 2021-01-01 01:00:00+00:00 	 max date: 2021-04-30 23:00:00+00:00
# 	dataset for channel_name Schlieffenstraße Stadtauswärts 	: length of dataset: 	 12155 	 min date: 2021-05-01 01:00:00+00:00 	 max date: 2022-09-20 03:00:00+00:00
# channel ID: 353239374 | standort: ['Stadt Ludwisburg'] | counter_sites: ['Schlieffenstraße'] | channel names: ['Schlieffenstraße Stadteinwärts B', 'Schlieffenstraße Stadteinwärts']
# 	dataset for channel_name Schlieffenstraße Stadteinwärts B 	: length of dataset: 	 2876 	 min date: 2021-01-01 01:00:00+00:00 	 max date: 2021-04-30 23:00:00+00:00
# 	dataset for channel_name Schlieffenstraße Stadteinwärts 	: length of dataset: 	 12155 	 min date: 2021-05-01 01:00:00+00:00 	 max date: 2022-09-20 03:00:00+00:00
# channel ID: 353239375 | standort: ['Stadt Ludwisburg'] | counter_sites: ['Schlieffenstraße'] | channel names: ['Schlieffenstraße Stadtauswärts B', 'Schlieffenstraße Stadtauswärts']
# 	dataset for channel_name Schlieffenstraße Stadtauswärts B 	: length of dataset: 	 2876 	 min date: 2021-01-01 01:00:00+00:00 	 max date: 2021-04-30 23:00:00+00:00
# 	dataset for channel_name Schlieffenstraße Stadtauswärts 	: length of dataset: 	 12155 	 min date: 2021-05-01 01:00:00+00:00 	 max date: 2022-09-20 03:00:00+00:00

# %% [markdown]
# --> Channels were renamed on the month change from April to May in 2021.
#
# If we correct for this renaming, location data is nested: channel IDs are nested withing channel names.

# %% [markdown]
# ### Example for the nesting of location data

# %%
# number of hourly measurements collected at different counting stations in Ludwigsburg
dat[dat['standort'] == 'Stadt Ludwisburg'].groupby(by=['counter_site', 'channel_name', 'channel_id']).size()
# Out:
# counter_site                      channel_name                                    channel_id
# Alleenstraße                      Alleenstraße Stadtauswärts A                    102041999     15291
#                                   Alleenstraße Stadtauswärts B                    104041999     15291
#                                   Alleenstraße Stadtauswärts C                    106041999     15291
#                                   Alleenstraße Stadteinwärts A                    101041999     15291
#                                   Alleenstraße Stadteinwärts B                    103041999     15291
#                                   Alleenstraße Stadteinwärts C                    105041999     15291
# Bismarckstraße                    Bismarckstraße Stadtauswärts                    353255195     14346
#                                                                                   353255197     14346
#                                                                                   353255199     14346
#                                   Bismarckstraße Stadteinwärts                    353255194     14346
#                                                                                   353255196     14346
#                                                                                   353255198     14346
# Friedrich-Ebert-Straße            Radweg C & D IN                                 353285275     14525
#                                   Radweg C & D OUT                                353285276     14525
#                                   Straße A & B IN                                 353285272     14525
#                                   Straße A & B OUT                                353285273     14525
# Fuchshof                          Fuchshof stadtauswärts                          353245993     15291
#                                                                                   353245995     15291
#                                   Fuchshof stadteinwärts                          353245992     15291
#                                                                                   353245994     15291
# Kesseläcker (Verl. Nussackerweg)  Kesseläcker (Verl. Nussackerweg) Stadtauswärts  353254100     14941
#                                                                                   353254102     14941
#                                   Kesseläcker (Verl. Nussackerweg) Stadteinwärts  353254099     14941
#                                                                                   353254101     14941
# Schlieffenstraße                  Schlieffenstraße Stadtauswärts                  353239373     12155
#                                                                                   353239375     12155
#                                   Schlieffenstraße Stadtauswärts A                353239373      2876
#                                   Schlieffenstraße Stadtauswärts B                353239375      2876
#                                   Schlieffenstraße Stadteinwärts                  353239372     12155
#                                                                                   353239374     12155
#                                   Schlieffenstraße Stadteinwärts A                353239372      2876
#                                   Schlieffenstraße Stadteinwärts B                353239374      2876
# Schlossstraße                     Schlossstraße Stadtauswärts A                   353254066     14605
#                                   Schlossstraße Stadtauswärts B                   353254068     14605
#                                   Schlossstraße Stadtauswärts C                   353254070     14605
#                                   Schlossstraße Stadteinwärts A                   353254065     14605
#                                   Schlossstraße Stadteinwärts B                   353254067     14605
#                                   Schlossstraße Stadteinwärts C                   353254069     14605
# Seestraße                         Seestraße Stadtauswärts                         353247049     15291
#                                                                                   353247051     15291
#                                   Seestraße Stadteinwärts                         353247050     15291
#                                                                                   353247052     15291
# Solitudeallee                     Solitudeallee Stadtauswärts                     353255205     14969
#                                   Solitudeallee Stadteinwärts                     353255204     14969
# Zugwiesen                         Zugwiesen Stadtauswärts                         353254108     14605
#                                                                                   353254110     14605
#                                                                                   353254112     14605
#                                   Zugwiesen Stadteinwärts                         353254107     14605
#                                                                                   353254109     14605
#                                                                                   353254111     14605
# dtype: int64

# %%
# to illustrate: zoom in on data at counter_site 'Fuchshof'
# number of hourly measurements collected at different combinations of channel_name x channel_id
dat[dat['counter_site'] == 'Fuchshof'].groupby(by=['channel_name', 'channel_id']).size()
# Out:
# channel_name            channel_id
# Fuchshof stadtauswärts  353245993     15291
#                         353245995     15291
# Fuchshof stadteinwärts  353245992     15291
#                         353245994     15291
# dtype: int64

# %% [markdown]
# Example:
#
# In Ludwigsburg, there is a counter site called "Fuchshof". At this counter site, we have two channel names ('Fuchshof stadteinwärts' und 'Fuchshof stadtauswärts').
# For each of the two channel names, there are two channel IDs ('Fuchshof stadteinwärts': 353245992 and 353245994; 'Fuchshof stadtauswärts': 353245993 and 353245995) which collect hourly data.
#
# So: Once every hour at the counter site 'Fuchshof', two values are collected for bike riders going downtown, and two values are collected for bike riders going out of town.

# %% [markdown]
# ### Check whether bike rider counts are given hourly

# %%
# number of measurements that we are given per day at one counting station
measurements_per_day = dat.groupby(by=['standort', 'counter_site', 'channel_name', 'channel_id', 'longitude', 'latitude', 'date'], as_index=False).size()
measurements_per_day.rename(columns = {'size':'measurements_per_day'}, inplace = True)
measurements_per_day
# Out:
#              standort                  counter_site  \
# 0      Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# 1      Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# 2      Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# 3      Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# 4      Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# ...               ...                           ...
# 59091       Stadt Ulm          Blautal Lupferbrücke
# 59092       Stadt Ulm          Blautal Lupferbrücke
# 59093       Stadt Ulm          Blautal Lupferbrücke
# 59094       Stadt Ulm          Blautal Lupferbrücke
# 59095       Stadt Ulm          Blautal Lupferbrücke
#
#                          channel_name  channel_id  longitude  latitude  \
# 0        FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# 1        FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# 2        FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# 3        FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# 4        FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# ...                               ...         ...        ...       ...
# 59091  Blautal Lupferbrücke Ri. Süden   104057246   9.957680  48.40080
# 59092  Blautal Lupferbrücke Ri. Süden   104057246   9.957680  48.40080
# 59093  Blautal Lupferbrücke Ri. Süden   104057246   9.957680  48.40080
# 59094  Blautal Lupferbrücke Ri. Süden   104057246   9.957680  48.40080
# 59095  Blautal Lupferbrücke Ri. Süden   104057246   9.957680  48.40080
#
#              date  measurements_per_day
# 0      2021-01-01                    24
# 1      2021-01-02                    24
# 2      2021-01-03                    24
# 3      2021-01-04                    24
# 4      2021-01-05                    24
# ...           ...                   ...
# 59091  2021-04-26                    24
# 59092  2021-04-27                    24
# 59093  2021-04-28                    24
# 59094  2021-04-29                    24
# 59095  2021-04-30                    23
#
# [59096 rows x 8 columns]

# %%
# summarize the data from above by showing for how many days (over all counting
# stations) x measurements per day are available
number_of_days_with_x_measurements_per_day = measurements_per_day.groupby(by=['measurements_per_day'], as_index=False).size()
number_of_days_with_x_measurements_per_day.rename(columns = {'size':'number_of_days_with_x_measurements_per_day'}, inplace = True)
number_of_days_with_x_measurements_per_day
# Out:
#    measurements_per_day  number_of_days_with_x_measurements_per_day
# 0                     1                                          16
# 1                     3                                           4
# 2                     4                                           4
# 3                     9                                           8
# 4                    10                                          16
# 5                    14                                           8
# 6                    15                                           1
# 7                    19                                           4
# 8                    23                                        1956
# 9                    24                                       57079

# %% [markdown]
# --> For most days, 24 hourly measurements (bike rider counts) are available. BUT: There are also days for which not 24 single 'hourly' bike rider counts are collected.

# %% [markdown]
# #### Check days with less than 24 hourly measurements

# %% [markdown]
# Check days for which only 23 'hourly' bike rider counts were collected and investigate why measurements are missing on these days.

# %%
# list days per counting station for which only 23 'hourly' measurements are available
measurements_per_day[measurements_per_day['measurements_per_day'] == 23]
# Out:
#              standort                  counter_site  \
# 30     Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# 58     Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# 89     Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# 119    Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# 150    Stadt Freiburg  FR1 Dreisam / Otto-Wels-Str.
# ...               ...                           ...
# 58975       Stadt Ulm          Blautal Lupferbrücke
# 59006       Stadt Ulm          Blautal Lupferbrücke
# 59034       Stadt Ulm          Blautal Lupferbrücke
# 59065       Stadt Ulm          Blautal Lupferbrücke
# 59095       Stadt Ulm          Blautal Lupferbrücke
#
#                          channel_name  channel_id  longitude  latitude  \
# 30       FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# 58       FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# 89       FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# 119      FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# 150      FR1 Dreisam / Hindenburgstr.   101014585   7.862301  47.99054
# ...                               ...         ...        ...       ...
# 58975  Blautal Lupferbrücke Ri. Süden   102057246   9.957680  48.40080
# 59006  Blautal Lupferbrücke Ri. Süden   104057246   9.957680  48.40080
# 59034  Blautal Lupferbrücke Ri. Süden   104057246   9.957680  48.40080
# 59065  Blautal Lupferbrücke Ri. Süden   104057246   9.957680  48.40080
# 59095  Blautal Lupferbrücke Ri. Süden   104057246   9.957680  48.40080
#
#              date  measurements_per_day
# 30     2021-01-31                    23
# 58     2021-02-28                    23
# 89     2021-03-31                    23
# 119    2021-04-30                    23
# 150    2021-05-31                    23
# ...           ...                   ...
# 58975  2021-04-30                    23
# 59006  2021-01-31                    23
# 59034  2021-02-28                    23
# 59065  2021-03-31                    23
# 59095  2021-04-30                    23
#
# [1956 rows x 8 columns]

# %% [markdown]
# The dates at which only 23 'hourly' bike rider counts were collected seem to be the end of the month.
# Inspect the first 'hourly' measurement of the next month - this measurement at midnight reflects the bike rider count of the last hour of the month before.

# %%
# first day of month, midnight.
first_day_of_month_dates_midnight = [pd.Timestamp('2021-0' + str(i)+ '-01T00', tz='UTC') for i in np.arange(1,10)]
dat[dat['timestamp'].isin(first_day_of_month_dates_midnight)]
# Out:
# Empty DataFrame
# Columns: [timestamp, iso_timestamp, zählstand, stand, standort, channel_name, channel_id, counter_site, counter_site_id, domain_name, domain_id, longitude, latitude, timezone, interval, counter_serial, date]
# Index: []

# %%
# first day of month, 1 am.
first_day_of_month_dates_1am = [pd.Timestamp('2021-0' + str(i)+ '-01T01', tz='UTC') for i in np.arange(1,10)]
dat[dat['timestamp'].isin(first_day_of_month_dates_1am)]
# Out:
#                       timestamp             iso_timestamp  zählstand  stand  \
# 0     2021-01-01 01:00:00+00:00  2021-01-01T01:00:00+0100          2      0
# 743   2021-01-01 01:00:00+00:00  2021-01-01T01:00:00+0100          0      0
# 1486  2021-01-01 01:00:00+00:00  2021-01-01T01:00:00+0100          0      0
# 2229  2021-01-01 01:00:00+00:00  2021-01-01T01:00:00+0100          0      0
# 2972  2021-01-01 01:00:00+00:00  2021-01-01T01:00:00+0100          0      0
# ...                         ...                       ...        ...    ...
# 64710 2021-09-01 01:00:00+00:00  2021-09-01T01:00:00+0200          2      0
# 65429 2021-09-01 01:00:00+00:00  2021-09-01T01:00:00+0200          0      0
# 66148 2021-09-01 01:00:00+00:00  2021-09-01T01:00:00+0200          0      0
# 66867 2021-09-01 01:00:00+00:00  2021-09-01T01:00:00+0200          0      4
# 67586 2021-09-01 01:00:00+00:00  2021-09-01T01:00:00+0200          3      4
#
#                standort                                     channel_name  \
# 0      Stadt Heidelberg                          Channel 1 Richtung West
# 743    Stadt Heidelberg                           Channel 2 Richtung Ost
# 1486   Stadt Heidelberg                          Channel 3 Richtung West
# 2229   Stadt Heidelberg                          Channel 5 Richtung West
# 2972   Stadt Heidelberg                           Channel 4 Richtung Ost
# ...                 ...                                              ...
# 64710    Stadt Konstanz  S-Bahn-Haltestelle Petershausen-Süd Cyclist OUT
# 65429  Stadt Ludwisburg                                  Straße A & B IN
# 66148  Stadt Ludwisburg                                 Straße A & B OUT
# 66867  Stadt Ludwisburg                                  Radweg C & D IN
# 67586  Stadt Ludwisburg                                 Radweg C & D OUT
#
#        channel_id                         counter_site  counter_site_id  \
# 0       101012161                                Plöck        100012161
# 743     102012161                                Plöck        100012161
# 1486    353221150                                Plöck        100012161
# 2229    353221152                                Plöck        100012161
# 2972    353221153                                Plöck        100012161
# ...           ...                                  ...              ...
# 64710   353267897  S-Bahn-Haltestelle Petershausen-Süd        300016793
# 65429   353285272               Friedrich-Ebert-Straße        300020056
# 66148   353285273               Friedrich-Ebert-Straße        300020056
# 66867   353285275               Friedrich-Ebert-Straße        300020056
# 67586   353285276               Friedrich-Ebert-Straße        300020056
#
#                                              domain_name  domain_id  \
# 0      NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 743    NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 1486   NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 2229   NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 2972   NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# ...                                                  ...        ...
# 64710  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 65429  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 66148  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 66867  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 67586  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
#
#        longitude   latitude                       timezone  interval  \
# 0       8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# 743     8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# 1486    8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# 2229    8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# 2972    8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# ...          ...        ...                            ...       ...
# 64710   9.173952  47.673801  (UTC+01:00) Europe/Berlin;DST        15
# 65429   9.206430  48.893033  (UTC+01:00) Europe/Berlin;DST        15
# 66148   9.206430  48.893033  (UTC+01:00) Europe/Berlin;DST        15
# 66867   9.206430  48.893033  (UTC+01:00) Europe/Berlin;DST        15
# 67586   9.206430  48.893033  (UTC+01:00) Europe/Berlin;DST        15
#
#       counter_serial        date
# 0        Y2H22032496  2021-01-01
# 743      Y2H22032496  2021-01-01
# 1486     Y2H22032496  2021-01-01
# 2229     Y2H22032496  2021-01-01
# 2972     Y2H22032496  2021-01-01
# ...              ...         ...
# 64710    COM21020460  2021-09-01
# 65429    Y2H21090554  2021-09-01
# 66148    Y2H21090554  2021-09-01
# 66867    Y2H21090554  2021-09-01
# 67586    Y2H21090554  2021-09-01
#
# [815 rows x 17 columns]

# %%
# second day of month, midnight.
first_day_of_month_dates_midnight = [pd.Timestamp('2021-0' + str(i)+ '-02T00', tz='UTC') for i in np.arange(1,10)]
dat[dat['timestamp'].isin(first_day_of_month_dates_midnight)]
# Out:
#                       timestamp             iso_timestamp  zählstand  stand  \
# 23    2021-01-02 00:00:00+00:00  2021-01-02T00:00:00+0100          2      0
# 766   2021-01-02 00:00:00+00:00  2021-01-02T00:00:00+0100          0      0
# 1509  2021-01-02 00:00:00+00:00  2021-01-02T00:00:00+0100          0      0
# 2252  2021-01-02 00:00:00+00:00  2021-01-02T00:00:00+0100          0      0
# 2995  2021-01-02 00:00:00+00:00  2021-01-02T00:00:00+0100          0      0
# ...                         ...                       ...        ...    ...
# 64733 2021-09-02 00:00:00+00:00  2021-09-02T00:00:00+0200          4      0
# 65452 2021-09-02 00:00:00+00:00  2021-09-02T00:00:00+0200          0      0
# 66171 2021-09-02 00:00:00+00:00  2021-09-02T00:00:00+0200          0      0
# 66890 2021-09-02 00:00:00+00:00  2021-09-02T00:00:00+0200          2      4
# 67609 2021-09-02 00:00:00+00:00  2021-09-02T00:00:00+0200          2      4
#
#                standort                                     channel_name  \
# 23     Stadt Heidelberg                          Channel 1 Richtung West
# 766    Stadt Heidelberg                           Channel 2 Richtung Ost
# 1509   Stadt Heidelberg                          Channel 3 Richtung West
# 2252   Stadt Heidelberg                          Channel 5 Richtung West
# 2995   Stadt Heidelberg                           Channel 4 Richtung Ost
# ...                 ...                                              ...
# 64733    Stadt Konstanz  S-Bahn-Haltestelle Petershausen-Süd Cyclist OUT
# 65452  Stadt Ludwisburg                                  Straße A & B IN
# 66171  Stadt Ludwisburg                                 Straße A & B OUT
# 66890  Stadt Ludwisburg                                  Radweg C & D IN
# 67609  Stadt Ludwisburg                                 Radweg C & D OUT
#
#        channel_id                         counter_site  counter_site_id  \
# 23      101012161                                Plöck        100012161
# 766     102012161                                Plöck        100012161
# 1509    353221150                                Plöck        100012161
# 2252    353221152                                Plöck        100012161
# 2995    353221153                                Plöck        100012161
# ...           ...                                  ...              ...
# 64733   353267897  S-Bahn-Haltestelle Petershausen-Süd        300016793
# 65452   353285272               Friedrich-Ebert-Straße        300020056
# 66171   353285273               Friedrich-Ebert-Straße        300020056
# 66890   353285275               Friedrich-Ebert-Straße        300020056
# 67609   353285276               Friedrich-Ebert-Straße        300020056
#
#                                              domain_name  domain_id  \
# 23     NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 766    NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 1509   NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 2252   NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 2995   NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# ...                                                  ...        ...
# 64733  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 65452  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 66171  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 66890  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
# 67609  NVBW - Nahverkehrsgesellschaft Baden- Württemberg       6598
#
#        longitude   latitude                       timezone  interval  \
# 23      8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# 766     8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# 1509    8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# 2252    8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# 2995    8.698543  49.409130  (UTC+01:00) Europe/Berlin;DST        15
# ...          ...        ...                            ...       ...
# 64733   9.173952  47.673801  (UTC+01:00) Europe/Berlin;DST        15
# 65452   9.206430  48.893033  (UTC+01:00) Europe/Berlin;DST        15
# 66171   9.206430  48.893033  (UTC+01:00) Europe/Berlin;DST        15
# 66890   9.206430  48.893033  (UTC+01:00) Europe/Berlin;DST        15
# 67609   9.206430  48.893033  (UTC+01:00) Europe/Berlin;DST        15
#
#       counter_serial        date
# 23       Y2H22032496  2021-01-01
# 766      Y2H22032496  2021-01-01
# 1509     Y2H22032496  2021-01-01
# 2252     Y2H22032496  2021-01-01
# 2995     Y2H22032496  2021-01-01
# ...              ...         ...
# 64733    COM21020460  2021-09-01
# 65452    Y2H21090554  2021-09-01
# 66171    Y2H21090554  2021-09-01
# 66890    Y2H21090554  2021-09-01
# 67609    Y2H21090554  2021-09-01
#
# [819 rows x 17 columns]

# %% [markdown]
# --> At midnight between two months, no bike rider count is collected (in contrast to e.g. the second day of the month where data is collected at midnight). Therefore, data from the last hour of each month is missing. This yields days for which only 23 'hourly' bike rider counts are available.

# %% [markdown]
# Check days for which less than 23 'hourly' bike rider counts are collected (per counting station).

# %%
# list days per counting station for which less than 23 'hourly' measurements are available
measurements_per_day[measurements_per_day['measurements_per_day'] < 23]
# Out:
#                standort        counter_site             channel_name  \
# 3804   Stadt Heidelberg  Bahnstadtpromenade             Channel 1 IN
# 4419   Stadt Heidelberg  Bahnstadtpromenade            Channel 2 OUT
# 5034   Stadt Heidelberg  Bahnstadtpromenade             Channel 3 IN
# 5649   Stadt Heidelberg  Bahnstadtpromenade            Channel 4 OUT
# 6264   Stadt Heidelberg  Bahnstadtpromenade             Channel 5 IN
# ...                 ...                 ...                      ...
# 55618  Stadt Ludwisburg           Zugwiesen  Zugwiesen Stadtauswärts
# 56228  Stadt Ludwisburg           Zugwiesen  Zugwiesen Stadteinwärts
# 56838  Stadt Ludwisburg           Zugwiesen  Zugwiesen Stadteinwärts
# 57448  Stadt Ludwisburg           Zugwiesen  Zugwiesen Stadteinwärts
# 58615   Stadt Offenburg     Hauptstraße neu          Hauptstraße neu
#
#        channel_id  longitude   latitude        date  measurements_per_day
# 3804    101056770   8.672679  49.397709  2022-09-07                     1
# 4419    102056770   8.672679  49.397709  2022-09-07                     1
# 5034    103056770   8.672679  49.397709  2022-09-07                     1
# 5649    104056770   8.672679  49.397709  2022-09-07                     1
# 6264    105056770   8.672679  49.397709  2022-09-07                     1
# ...           ...        ...        ...         ...                   ...
# 55618   353254112   9.240983  48.909329  2021-01-29                    10
# 56228   353254107   9.240983  48.909329  2021-01-29                    10
# 56838   353254109   9.240983  48.909329  2021-01-29                    10
# 57448   353254111   9.240983  48.909329  2021-01-29                    10
# 58615   101036542   7.942310  48.467990  2022-07-12                    15
#
# [61 rows x 8 columns]

# %%
# counting station
city_name = 'Stadt Ludwisburg'
counter_site = 'Schlossstraße'
channel_names = [
    'Schlossstraße Stadtauswärts A',
    'Schlossstraße Stadtauswärts B',
    'Schlossstraße Stadtauswärts C',
    'Schlossstraße Stadteinwärts A',
    'Schlossstraße Stadteinwärts B',
    'Schlossstraße Stadteinwärts C'
    ]
dates = [datetime(2021,1,29).date()]

# extract data for counting station
dat_10_measurements_per_day = dat[(dat.standort == city_name) & (dat.counter_site == counter_site) & (dat.channel_name.isin(channel_names)) & (dat.date.isin(dates))]
print('Earliest hourly bike rider count was collected at: ', min(dat_10_measurements_per_day['timestamp']))
# Out:
# Earliest hourly bike rider count was collected at:  2021-01-29 15:00:00+00:00

# %% [markdown]
# --> Data collection at 'Stadt Ludwisburg | Schlossstraße |  ['Schlossstraße Stadtauswärts A', 'Schlossstraße Stadtauswärts B', 'Schlossstraße Stadtauswärts C', 'Schlossstraße Stadteinwärts A', 'Schlossstraße Stadteinwärts B', 'Schlossstraße Stadteinwärts C'] started at 3pm on 2021-01-29. --> Should exclude this day at this counting station because daily sum does not reflect the whole day.

# %% [markdown]
# ### Inspect remaining unkown columns

# %% [markdown]
# #### 'stand'
#
# As already seen in the beginning in 'overview_dat', values in the column 'stand' are only $0$ or $4$. In the following, we figure out what this indicates.

# %%
# find IDs of channels for which we have measurements with both 'stand==0' and 'stand==4'

# find channel IDs for which we observe stand==0
cid_stand0 = set(dat[dat['stand'] == 0]['channel_id'])
print('We observe stand==0 only for channels with IDs', np.sort(list(cid_stand0)))

# find channel IDs for which we observe stand==4
cid_stand4 = set(dat[dat['stand'] == 4]['channel_id'])
print('We observe stand==4 only for channels with IDs', np.sort(list(cid_stand4)))

# find channel IDs for which we observe stand==0 AND stand==4
cid_stand0and4 = np.sort(list(cid_stand4.intersection(cid_stand0)))
print('We observe stand==0 AND stand==4 only for channels with IDs', cid_stand0and4)
print('--> For all channels for which we observe stand==4, we also observe stand==0.')
# Out:
# We observe stand==0 only for channels with IDs [101012161 101012608 101013034 101014511 101014585 101017109 101036542
#  101041999 101046462 101049883 101049901 101056769 101056770 101057246
#  102012161 102012608 102013034 102017109 102041999 102046462 102049883
#  102049901 102056769 102056770 102057246 103013034 103041999 103046462
#  103049883 103056769 103056770 103057246 104041999 104046462 104049883
#  104056769 104056770 104057246 105041999 105056770 106041999 106056770
#  353221137 353221138 353221150 353221152 353221153 353221155 353221311
#  353221316 353221319 353221324 353221750 353221752 353234627 353239372
#  353239373 353239374 353239375 353245992 353245993 353245994 353245995
#  353247049 353247050 353247051 353247052 353254065 353254066 353254067
#  353254068 353254069 353254070 353254099 353254100 353254101 353254102
#  353254107 353254108 353254109 353254110 353254111 353254112 353255194
#  353255195 353255196 353255197 353255198 353255199 353255204 353255205
#  353262797 353262798 353267891 353267892 353267896 353267897 353285272
#  353285273 353285275 353285276 353331384 353331389 353331391 353331395
#  353331397 353331399 353331400 353331402]
# We observe stand==4 only for channels with IDs [101014511 101017109 102017109 353239372 353239373 353239374 353239375
#  353285272 353285273 353285275 353285276]
# We observe stand==0 AND stand==4 only for channels with IDs [101014511 101017109 102017109 353239372 353239373 353239374 353239375
#  353285272 353285273 353285275 353285276]
# --> For all channels for which we observe stand==4, we also observe stand==0.

# %%
# visualize what 'stand' indicates

# sum counts of one day at one counting station, seperated by stand
counters_by_daytype_daily_with_stand = dat.groupby(by=['standort', 'counter_site', 'channel_name', 'channel_id', 'stand', 'longitude', 'latitude', 'date'], as_index=False)['zählstand'].sum()

# for each channel ID for which we observe both stand==0 AND stand==4
for id4 in cid_stand0and4:

    # extract data of this channel
    dat_for_id = counters_by_daytype_daily_with_stand[counters_by_daytype_daily_with_stand['channel_id'] == id4]
    
    # plot daily bike rider counts collected by this channel,
    # seperate between different 'stand'-values

    # initialize figure
    plt.figure()
    
    # for each value of 'stand', plot daily number of bike rider counts
    for stand in [0, 4]:
        plt.plot(
            dat_for_id[dat_for_id['stand'] == stand]['date'],
            dat_for_id[dat_for_id['stand'] == stand]['zählstand'],
            label='stand=='+str(stand))
    
    # add title and legend
    plt.title('channel ID: ' + str(id4) + '\nstandort: ' + str(set(dat_for_id['standort'])) + '\ncounter sites: ' + str(set(dat_for_id['counter_site'])) + '\nchannel_names: ' + str(set(dat_for_id['channel_name'])))
    plt.legend()

# %% [markdown]
# Apparently, "stand" differentiates different time periods. So, for our analysis goal, we can ignore this factor.

# %% [markdown]
# #### 'interval'
#
# The 'interval' column takes the same value for all measurements. So, for our analysis goal, we can ignore this factor.

# %% [markdown]
# #### 'domain_name' and 'domain_id'
#
# The 'domain_name' and 'domain_id' columns takes the same value for all measurements. So, for our analysis goal, we can ignore this factor.

# %% [markdown]
# ### Compare characteristics of data from 2021 with 2022

# %%
# extract data for 2021 / 2022
dat21 = dat.loc[dat['date'] < date(2022, 1, 1)]
dat22 = dat.loc[dat['date'] > date(2021, 12, 31)]

# compare in which cities data was collected
print('For the following cities, data was only collected in 2021:', np.setdiff1d(dat21['standort'], dat22['standort']))
print('For the following cities, data was only collected in 2022:', np.setdiff1d(dat22['standort'], dat21['standort']))
print()


# compare for which channel IDs data was collected

# unique Channel IDs in 2021 that are not in 2022
unique_2021_channelIDs = np.setdiff1d(dat21.groupby(['standort', 'counter_site', 'channel_id'], as_index=False).size()['channel_id'], dat22.groupby(['standort', 'counter_site', 'channel_id'], as_index=False).size()['channel_id'])
# print
print('For the following channel IDs, data was only collected in 2021:')
for id in unique_2021_channelIDs:
    data_for_channel_id = dat21[dat21['channel_id'] == id]
    print('channel ID:', id, ' | city:', set(data_for_channel_id['standort']), ' | counter site:', set(data_for_channel_id['counter_site']), '| channel name:', set(data_for_channel_id['channel_name']))
print()

# unique Channel IDs in 2022 that are not in 2021
unique_2022_channelIDs = np.setdiff1d(dat22.groupby(['standort', 'counter_site', 'channel_id'], as_index=False).size()['channel_id'], dat21.groupby(['standort', 'counter_site', 'channel_id'], as_index=False).size()['channel_id'])
# print
print('For the following channel IDs, data was only collected in 2022:')
for id in unique_2022_channelIDs:
    data_for_channel_id = dat22[dat22['channel_id'] == id]
    print('channel ID:', id, ' | city:', set(data_for_channel_id['standort']), ' | counter site:', set(data_for_channel_id['counter_site']), '| channel name:', set(data_for_channel_id['channel_name']))
# Out:
# For the following cities, data was only collected in 2021: ['Stadt Ulm']
# For the following cities, data was only collected in 2022: []
#
# For the following channel IDs, data was only collected in 2021:
# channel ID: 101057246  | city: {'Stadt Ulm'}  | counter site: {'Blautal Lupferbrücke'} | channel name: {'Blautal Lupferbrücke Ri. Stadt'}
# channel ID: 102057246  | city: {'Stadt Ulm'}  | counter site: {'Blautal Lupferbrücke'} | channel name: {'Blautal Lupferbrücke Ri. Süden'}
# channel ID: 103057246  | city: {'Stadt Ulm'}  | counter site: {'Blautal Lupferbrücke'} | channel name: {'Blautal Lupferbrücke Ri. Stadt'}
# channel ID: 104057246  | city: {'Stadt Ulm'}  | counter site: {'Blautal Lupferbrücke'} | channel name: {'Blautal Lupferbrücke Ri. Süden'}
# channel ID: 353262797  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn Haltestelle Fürstenberg'} | channel name: {'S-Bahn Haltestelle Fürstenberg'}
# channel ID: 353262798  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn-Haltestelle Petershausen-Süd'} | channel name: {'S-Bahn-Haltestelle Petershausen-Süd Fahrräder'}
#
# For the following channel IDs, data was only collected in 2022:
# channel ID: 353331384  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn Haltestelle Fürstenberg'} | channel name: {'S-Bahn Haltestelle Fürstenberg [Bike IN]'}
# channel ID: 353331389  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn Haltestelle Fürstenberg'} | channel name: {'S-Bahn Haltestelle Fürstenberg [Bike IN]'}
# channel ID: 353331391  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn Haltestelle Fürstenberg'} | channel name: {'S-Bahn Haltestelle Fürstenberg [Bike OUT]'}
# channel ID: 353331395  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn Haltestelle Fürstenberg'} | channel name: {'S-Bahn Haltestelle Fürstenberg [Bike OUT]'}
# channel ID: 353331397  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn-Haltestelle Petershausen-Süd'} | channel name: {'S-Bahn-Haltestelle Petershausen-Süd [Bike IN]'}
# channel ID: 353331399  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn-Haltestelle Petershausen-Süd'} | channel name: {'S-Bahn-Haltestelle Petershausen-Süd [Bike IN]'}
# channel ID: 353331400  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn-Haltestelle Petershausen-Süd'} | channel name: {'S-Bahn-Haltestelle Petershausen-Süd [Bike OUT]'}
# channel ID: 353331402  | city: {'Stadt Konstanz'}  | counter site: {'S-Bahn-Haltestelle Petershausen-Süd'} | channel name: {'S-Bahn-Haltestelle Petershausen-Süd [Bike OUT]'}

# %% [markdown]
# ## Summary

# %% [markdown]
# One row represents one hourly bike rider count measurement.
# Each column represents an attribute of a measurement:
# | column name | description |
# | --- | --- |
# |timestamp | point in time when the measurement was collected |
# |iso_timestamp | point in time when the measurement was collected; iso-formatted |
# |timezone | time zone of the points in time that are given in the timestamp-column |
# |standort | name of the city in which the measurement was collected |
# |counter_site | description (in words) where the measurement was collected, e.g., name of a street |
# |counter_site_id | ID of counter_site; equally informative as counter_site |
# |counter_serial | serial number (?) of counter_site; equally informative as counter_site |
# |longitude | coordinate of counter site; together with latitude: equally informative as counter_site |
# |latitude | coordinate of counter site; together with longitude: equally informative as counter_site |
# |channel_name | specification (in words) how measurements are collected at a counter site; e.g. direction of travel |
# |channel_id | ID of channel. At one counter site, different count series are measured in parallel, e.g., in different directions of travel (but also in parallel for the same direction of travel). channel_id discriminates between different count series, collected at one counter site. It is more specific than channel_name, i.e., channel_id helps to discriminate between different counts in the same direction of travel while channel_name might only specify the direction of travel. |
# |zählstand | hourly sum of bike riders |
# |stand | differentiates between different time periods for a count series at one channel ID (for most datapoints, it takes value 0) |
# |domain_name | name of the organization that published the data online (takes value 'NVBW - Nahverkehrsgesellschaft Baden- Württemberg' for all datapoints) |
# |domain_id | ID of the organization that published the data online (takes value 6598 for all datapoints) |
# |interval | ? (takes value 15 for all datapoints) |

# %%
# overview over the data (listed here again for illustration)
# list how many distinct values are contained in each column and show example
# values for each column
overview_df
# Out:
#             colname number_of_unique_values_in_column  \
# 0         timestamp                             15291
# 1     iso_timestamp                             15291
# 2         zählstand                               740
# 3             stand                                 2
# 4          standort                                 6
# 5      channel_name                                77
# 6        channel_id                               109
# 7      counter_site                                25
# 8   counter_site_id                                25
# 9       domain_name                                 1
# 10        domain_id                                 1
# 11        longitude                                25
# 12         latitude                                25
# 13         timezone                                 2
# 14         interval                                 1
# 15   counter_serial                                25
#
#                                        example_values
# 0   [2021-04-16T11:00:00+0000, 2021-02-20T16:00:00...
# 1   [2021-08-15T06:00:00+0200, 2021-08-06T13:00:00...
# 2                                [665, 301, 293, 142]
# 3                                              [4, 0]
# 4   [Stadt Konstanz, Stadt Heidelberg, Stadt Freib...
# 5   [S-Bahn Haltestelle Fürstenberg Cyclist OUT, Z...
# 6        [102057246, 101049883, 103049883, 353255196]
# 7   [Hardtstraße, Bismarckstraße, Gaisbergstraße, ...
# 8        [100057246, 100013034, 300015452, 300020056]
# 9   [NVBW - Nahverkehrsgesellschaft Baden- Württem...
# 10                                             [6598]
# 11    [9.17190492153168, 7.8623013, 7.83717, 9.17467]
# 12  [48.90932869563591, 48.883562725714086, 49.406...
# 13  [(UTC+01:00) Europe/Paris;DST, (UTC+01:00) Eur...
# 14                                               [15]
# 15  [COM21020460, Y2H20083632, Y2H18106689, Y2H181...

# %% [markdown]
# Given are hourly bike rider counts, collected 24 times a day.
# There are days on which some 'hourly' measurements are missing.
# Not every counting station collected data for the whole year 2021.
#
# The information about the location of a counting station is nested:
# There are different 'standort' (cities).
# Within each of 'standort' (city), there are different 'counter_site' (e.g., different streets).
# And at each 'counter_site', different count series (so-called "channels") are measured in parallel, e.g., in different directions of travel. 'channel_name' / 'channel_id' discriminates between these different channels. The 'channel_name' provides a distinction between channels that is more coarse than the distinction made by 'channel_id'; i.e., 'channel_id' is nested within 'channel_name'. So, at each 'channel_name', there can be multiple 'channel_id'.
#
# Example:
#
# In 'Stadt Freiburg' ('standort'), there are 3 'counter_sites' ('FR1 Dreisam / Otto-Wels-Str.', 'FR2 Güterbahn / Ferd.-Weiß-Str.', and 'FR3 Eschholzstr. / Egonstr.'). At each of them, there are different 'channel_name'. (In Freiburg, there is a 1-to-1-mapping between 'channel_name' and 'channel_id'. So here, for every 'channel_name', there is exactly one 'channel_id'.)
#
# Example to illustrate channel IDs:
#
# In Ludwigsburg, there is a counter site called "Fuchshof". At this counter site, we have two channel names ('Fuchshof stadteinwärts' und 'Fuchshof stadtauswärts').
# For each of the two channel names, there are two channel IDs ('Fuchshof stadteinwärts': 353245992 and 353245994; 'Fuchshof stadtauswärts': 353245993 and 353245995) which collect hourly data.
# So: Once every hour at the counter site 'Fuchshof', two values are collected for bike riders going downtown, and two values are collected for bike riders going out of town.
#
# Peculiarities to keep in mind for data processing and data cleaning:
# - Dates of measurements collected at midnight need to be adjusted (such that bike riders that passed the counting station in the last hour of a day are still added to the count for this day and not to the next)
# - There is one exception of the location nesting: In Ludwigsburg (counter_site: Schlieffenstraße), there are channel IDs which map to different channel names. This is due to a renaming of these channels in the middle of the year.
# - 'Ludwigsburg' is misspelled in the raw dataset.
